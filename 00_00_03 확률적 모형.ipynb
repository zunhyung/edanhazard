# %% [markdown]
# ## 3. 확률적 모형의 의미
# ### 3.1 확률적 모형
# - 확률적 관계를 가질 때
#
# $$
# P(Y=y) =
# \begin{cases}
# \frac{1}{3} & y = 가위, 바위, 보 \\\\
# 0           & otherwise
# \end{cases}
# $$

# %% [markdown]
# ### (1)  Game 3:  확률적 모형
# - A와 B가 임의로(random하게) 가위-바위-보 Game을 한다

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### (2) Discussion 1
# - A가 B를 항상 이길 수 있는가?
# - 왜 그런가?

# %% [markdown]
# ### (3) Discussion 2
# - A가 B를 이기는 비율은 얼마일까?
# - 실제로 그런가? 가위-바위-보 Game을 10회 진행하여 A가 이기는 비율과 B가 이기는 비율을 python code로 구현하여 구해보라

# %% [markdown]
# - 가위-바위-보 Game을 1000회 진행하여 A가 이기는 비율과 B가 이기는 비율을 python code로 구현하여 구해보라

# %% [markdown]
# ### (4) Discussion 3
# - 확정적 상황의 예 5개와 확률적 상황의 예 5개씩을 나열해보시오

# %% [markdown]
# ## 우리가 다룬 문제의 상황과 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 확률적 상황을 표현할 수 있는 방법은 확률분포를 사용하는 것임
# $ \ \ $ $\checkmark \ $ 위의 가위바위보 Game에서 player A의 선택은 다음과 같은 확률분포로 설명할 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)
